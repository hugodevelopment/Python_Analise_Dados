# %%
import pandas as pd
poke = pd.read_csv('pokemon_data.csv')
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# **Lendo as informações do dataframe**

# %%
# Aqui acessamos todas as colunas do nosso dataframe do pokemon
poke.columns

# Aqui acessamos os dados da coluna Name
poke["Name"]

# Aqui acessamos os dados da coluna Name dos 5 primeiros elementos
poke["Name"][0:5]

# Aqui acessamos mais de uma coluna, sendo Name e Hp com seus 5 primeiros elementos
poke[["Name", "HP"]][0:5]
# Out:
#                     Name  HP
# 0              Bulbasaur  45
# 1                Ivysaur  60
# 2               Venusaur  80
# 3  VenusaurMega Venusaur  80
# 4             Charmander  39

# %% [markdown]
# **Lendo as linhas(Row) dos dataframe com iloc e loc**
# * loc selects rows and columns with specific labels
# *  iloc selects rows and columns at specific integer positions

# %% [markdown]
# Utilizando o loc selecionando linhas e colunas com nomes especificos

# %%
# Vamos selecionar as colunas do ivysaur (1) e Venusaur (2) pelo index utilizando o loc
poke.loc[[1,2]]
# Vamos selecionar as colunas do ivysaur (1) e Venusaur (2) pelo index utilizando o loc, agora com as colunas de Name e Legendary
poke.loc[[1,2] , ["Name","Legendary"]]
# Out:
#        Name  Legendary
# 1   Ivysaur      False
# 2  Venusaur      False

# %% [markdown]
# **Utilizando o iloc selecionando linhas e colunas com as posições**

# %%
# Lendo linhas
poke.iloc[0:4]
# Lendo a linha(row) do Venusaur (linha(2) a posição, coluna(1) que é o nome)
poke.iloc[2,1]
# Encontrando o charmander(linha(4) a posição, coluna(1) que é o nome do pokemon)
charmander = poke.iloc[4,1]
charmander
# Out:
# 'Charmander'

# %% [markdown]
# **Iterando os valores de index e linhas**

# %%
#Criando um loop para percorrer as linhas do dataframe utilizando o iterrows
for i, row in poke.iterrows():
     print(i, row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
# Criando um loop para percorrer as linhas(rows com i) e selecionar as colunas Name e Hp do dataframe
for i in range(len(poke)):
      print(poke.loc[i,"Name"], poke.loc[i,"HP"], poke.loc[i,"Type 1"])
# Out:
# Bulbasaur 45 Grass
# Ivysaur 60 Grass
# Venusaur 80 Grass
# VenusaurMega Venusaur 80 Grass
# Charmander 39 Fire
# Charmeleon 58 Fire
# Charizard 78 Fire
# CharizardMega Charizard X 78 Fire
# CharizardMega Charizard Y 78 Fire
# Squirtle 44 Water
# Wartortle 59 Water
# Blastoise 79 Water
# BlastoiseMega Blastoise 79 Water
# Caterpie 45 Bug
# Metapod 50 Bug
# Butterfree 60 Bug
# Weedle 40 Bug
# Kakuna 45 Bug
# Beedrill 65 Bug
# BeedrillMega Beedrill 65 Bug
# Pidgey 40 Normal
# Pidgeotto 63 Normal
# Pidgeot 83 Normal
# PidgeotMega Pidgeot 83 Normal
# Rattata 30 Normal
# Raticate 55 Normal
# Spearow 40 Normal
# Fearow 65 Normal
# Ekans 35 Poison
# Arbok 60 Poison
# Pikachu 35 Electric
# Raichu 60 Electric
# Sandshrew 50 Ground
# Sandslash 75 Ground
# Nidoran (Female) 55 Poison
# Nidorina 70 Poison
# Nidoqueen 90 Poison
# Nidoran (Male) 46 Poison
# Nidorino 61 Poison
# Nidoking 81 Poison
# Clefairy 70 Fairy
# Clefable 95 Fairy
# Vulpix 38 Fire
# Ninetales 73 Fire
# Jigglypuff 115 Normal
# ...

# %%
#  Criando um loop para percorrer as linhas(rows), porém selecionando as colunas com o iloc[i,posição da coluna]
for i in range(len(poke)):
      print(poke.iloc[i,0], poke.iloc[i,1])
# Out:
# 1 Bulbasaur
# 2 Ivysaur
# 3 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 6 CharizardMega Charizard X
# 6 CharizardMega Charizard Y
# 7 Squirtle
# 8 Wartortle
# 9 Blastoise
# 9 BlastoiseMega Blastoise
# 10 Caterpie
# 11 Metapod
# 12 Butterfree
# 13 Weedle
# 14 Kakuna
# 15 Beedrill
# 15 BeedrillMega Beedrill
# 16 Pidgey
# 17 Pidgeotto
# 18 Pidgeot
# 18 PidgeotMega Pidgeot
# 19 Rattata
# 20 Raticate
# 21 Spearow
# 22 Fearow
# 23 Ekans
# 24 Arbok
# 25 Pikachu
# 26 Raichu
# 27 Sandshrew
# 28 Sandslash
# 29 Nidoran (Female)
# 30 Nidorina
# 31 Nidoqueen
# 32 Nidoran (Male)
# 33 Nidorino
# 34 Nidoking
# 35 Clefairy
# 36 Clefable
# 37 Vulpix
# 38 Ninetales
# 39 Jigglypuff
# 40 Wigglytuff
# 41 Zubat
# 42 Golbat
# 43 Oddish
# 44 Gloom
# 45 Vileplume
# 46 Paras
# 47 Parasect
# 48 Venonat
# 49 Venomoth
# 50 Diglett
# 51 Dugtrio
# 52 Meowth
# 53 Persian
# 54 Psyduck
# 55 Golduck
# 56 Mankey
# 57 Primeape
# 58 Growlithe
# 59 Arcanine
# 60 Poliwag
# 61 Poliwhirl
# ...

# %%
# Também é possível utilizar o for de forma natural para realizar algum cálculo e depois transformar em um novo dataframe
for i in poke:
    new_hp = poke["HP"]*3
pd.DataFrame(new_hp).head(10)
# Out:
#     HP
# 0  135
# 1  180
# 2  240
# 3  240
# 4  117
# 5  174
# 6  234
# 7  234
# 8  234
# 9  132

# %% [markdown]
# **Selecionando colunas com condições especificas**
#
# **Para criar condições utilizamos:**
#
# Use & | ~ (not and, or, not)
#
# Enclose each conditional expression in parentheses when using comparison operators

# %%
# Aqui criamos um dataframe com as informações do tipo1 igual ao estilo fogo, que é o estilo principal
Tipo_fogo = poke.loc[poke['Type 1']=="Fire"]
Tipo_fogo

# Aqui criamos um dataframe com duas condições, sendo elas o tipo 1 dark E tipo 2 fire, ou seja, apenas quando as duas forem true
Tipo_fogo_dark = poke.loc[(poke['Type 1']=="Dark") & (poke["Type 2"]=="Fire")]
Tipo_fogo_dark

# Aqui criamos um dataframe com 3 condições, sendo elas o tipo 1 dark E tipo 2 fire, ou seja, apenas quando as 3 forem true
Tipo_Poison_Grass = poke.loc[(poke["Type 1"]=="Grass") & (poke["Type 2"]=="Poison") & (poke["Generation"]==1)]
Tipo_Poison_Grass
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
# 49  44                  Gloom  Grass  Poison  60      65       70       85
# 50  45              Vileplume  Grass  Poison  75      80       85      110
# 75  69             Bellsprout  Grass  Poison  50      75       35       70
# 76  70             Weepinbell  Grass  Poison  65      90       50       85
# 77  71             Victreebel  Grass  Poison  80     105       65      100
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# ...

# %%
# Nesse exemplo criaremos um dataframe onde é necessário apenas uma das condições sendo verdadeira(True)
Tipo_lendario = poke.loc[(poke["Legendary"]==True) | (poke["Generation"]==1)]
Tipo_lendario.head(50)
# Out:
#      #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0    1                  Bulbasaur     Grass  Poison   45      49       49
# 1    2                    Ivysaur     Grass  Poison   60      62       63
# 2    3                   Venusaur     Grass  Poison   80      82       83
# 3    3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4    4                 Charmander      Fire     NaN   39      52       43
# 5    5                 Charmeleon      Fire     NaN   58      64       58
# 6    6                  Charizard      Fire  Flying   78      84       78
# 7    6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8    6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9    7                   Squirtle     Water     NaN   44      48       65
# 10   8                  Wartortle     Water     NaN   59      63       80
# 11   9                  Blastoise     Water     NaN   79      83      100
# ...

# %%
# Aqui temos 3 condições que devem ser verdadeiras, como Type 1, Type 2 e Legendary, ou, caso a geração do pokemon seja a 3º
Tipo_generation = poke.loc[(poke["Type 1"]=="Grass") & (poke["Type 2"]=="Flying") & (poke["Legendary"]==False) | (poke["Generation"] == 3)]
Tipo_generation
# Out:
#        #                 Name   Type 1   Type 2   HP  Attack  Defense  \
# 202  187               Hoppip    Grass   Flying   35      35       40
# 203  188             Skiploom    Grass   Flying   55      45       50
# 204  189             Jumpluff    Grass   Flying   75      55       70
# 272  252              Treecko    Grass      NaN   40      45       35
# 273  253              Grovyle    Grass      NaN   50      65       45
# ..   ...                  ...      ...      ...  ...     ...      ...
# 427  385              Jirachi    Steel  Psychic  100     100      100
# 428  386   DeoxysNormal Forme  Psychic      NaN   50     150       50
# 429  386   DeoxysAttack Forme  Psychic      NaN   50     180       20
# 430  386  DeoxysDefense Forme  Psychic      NaN   50      70      160
# 431  386    DeoxysSpeed Forme  Psychic      NaN   50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 202       35       55     50           2      False
# ...

# %%
poke.loc[poke['HP'] > 50, ['Generation','Legendary']] = ['Test 1', 'Test 2']
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# 0         65       65     45          1     False
# ...

# %% [markdown]
# **Sorting values**
#
# Pandas sort_values() function sorts a data frame in Ascending or Descending order of passed Column.

# %%
# Embaralhando os dados a partir da coluna Name na ordem crescente que é o padrão
poke.sort_values('Name')

# Embaralhando os dados em ordem decrescente
poke.sort_values('Name', ascending= False)

# Embaralhando duas colunas
poke.sort_values(['Name', 'HP'], ascending = True)

# Embaralhando duas colunas com Type 1 na ordem crescente e HP na ordem decrescente
poke.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# **Adding new collunms**

# %%
# Criando uma nova coluna no dataframe poke
poke['Media'] = (poke['HP'] + poke['Attack'] + poke['Defense'])/3
poke.head(5)

# Podemos utilizar a função assign para criar uma coluna com o valor HP original vezes 2
poke2 = poke.assign(HP2 = poke['HP']*2)
poke2.head(5)

# Podemos realizar calculos ao criar novas colunas
poke["Attack%"] = poke['Attack'] * 0.1
poke.head(5)

# Criando uma coluna com uma função que avalia o ataque utilizando if and elses
def AttackValues(value):
    if value < 50:
        return 'Baixo Ataque'
    elif 50 < value < 70:
        return 'Medio Ataque'
    elif 70 < value < 90:
        return 'Bom Ataque'
    else:
         return 'Otimo Ataque'        

poke['goodAttack'] = poke['Attack'].map(AttackValues)
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary       Media  Attack%  \
# ...

# %% [markdown]
# **Filtering Data**
#
# **Vamos aprender metodos para filtrar nossos dados**
#
# **Sites que me ajudaram**
#
# 1º https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html

# %%
# 1º Operadores Lógicos: Podemos usar &, |, strings para fazer nossa seleção
poke[(poke['Attack']> 150)]
poke[(poke['Attack'] > 130) & (poke['Defense'] > 130)]
poke[(poke['Name'] > 'Charmeleon')]

# 2º Utilizado o isin metodo para filtrar apenas os elementos do tipo fogo e water e seus nomes
type = ['Fire', 'Water']
poke[poke['Type 1'].isin(type)]

# Utilizando o isin com números
hp = [130,150]
poke[poke['HP'].isin(hp)]

# Criando um isin com duas condições
poke[(poke['Type 1'].isin(type)) & (poke['HP'].isin(hp))]

#3 Utilizando o Srt acessor

# Escolhendo os pokemons que o nome começam com A
poke[poke["Name"].str.startswith('A')] 

# Escolhendo os pokemons que contém a letra J
poke[poke["Name"].str.contains("J")]

# Escolhendo os pokemons que contém J e com o HP maior que 70
poke[(poke["Name"].str.contains("J")) & (poke["HP"]> 70)]

# Query selector
# poke.query[('poke["Name"] == "Pikachu" & poke["HP"]> 120')]

# # Nlargest
# poke.nlargest(2, poke["HP"]
# Out:
#        #        Name  Type 1   Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 44    39  Jigglypuff  Normal    Fairy  115      45       20       45       25
# 204  189    Jumpluff   Grass   Flying   75      55       70       55       95
# 427  385     Jirachi   Steel  Psychic  100     100      100      100      100
# 654  593   Jellicent   Water    Ghost  100      60       70       85      105
#
#      Speed  Generation  Legendary       Media  Attack%    goodAttack
# 44      20           1      False   60.000000      4.5  Baixo Ataque
# 204    110           2      False   66.666667      5.5  Medio Ataque
# 427    100           3       True  100.000000     10.0  Otimo Ataque
# 654     60           5      False   76.666667      6.0  Medio Ataque

# %% [markdown]
# **Utilizando Regex**

# %%
import re
#Aqui utilizamos o pacote regex para selecionar os pokemons com tipo 1 igual fogo ou grama, flags = re.I 
#flags = re.I permiti que não tenha problema ser maiusculo ou minisculo
Tipo_Fogo = poke.loc[poke["Type 1"].str.contains("fire|grass", flags = re.I) & (poke["HP"]> 100)]
Tipo_Fogo

# Selecionando pokemons começando com CH
name_ch = poke.loc[(poke['Name']).str.contains("^ch[a-z]*", flags = re.I)]
name_ch
# Out:
#        #                       Name   Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander     Fire       NaN   39      52       43
# 5      5                 Charmeleon     Fire       NaN   58      64       58
# 6      6                  Charizard     Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X     Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire    Flying   78     104       78
# 121  113                    Chansey   Normal       NaN  250       5        5
# 166  152                  Chikorita    Grass       NaN   45      49       65
# 184  170                   Chinchou    Water  Electric   75      38       38
# 391  358                   Chimecho  Psychic       NaN   65      50       70
# 435  390                   Chimchar     Fire       NaN   44      58       44
# 467  420                    Cherubi    Grass       NaN   45      35       45
# ...

# %% [markdown]
# **Agregando valores com group by, count e sum**
#
# **Pandas groupby is used for grouping the data according to the categories and apply a function to the categories. It also helps to aggregate data efficiently.**

# %%
# Aqui estamos agrupando os pokemons por geração
primeiros = poke.groupby('Generation')
# Agora estamos agrupando os 1º de cada geração(1 a 6)
primeiros.first()
# Out:
#               #       Name   Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# Generation
# 1             1  Bulbasaur    Grass    Poison   45      49       49       65
# 2           152  Chikorita    Grass    Flying   45      49       65       49
# 3           252    Treecko    Grass    Dragon   40      45       35       65
# 4           387    Turtwig    Grass    Ground   55      68       64       45
# 5           494    Victini  Psychic      Fire  100     100      100      100
# 6           650    Chespin    Grass  Fighting   56      61       65       48
#
#             Sp. Def  Speed  Legendary       Media  Attack%    goodAttack
# Generation
# 1                65     45      False   47.666667      4.9  Baixo Ataque
# 2                65     45      False   53.000000      4.9  Baixo Ataque
# 3                55     70      False   40.000000      4.5  Baixo Ataque
# 4                55     31      False   62.333333      6.8  Medio Ataque
# ...

# %% [markdown]
# **Com o get_group é possivel ver todas as info das gerações (1 a 6)**

# %%
# exibindo as infos apenas da 1º geração com os 10 primeiros pokemons utilizando o head(10)
primeiros.get_group(1).head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary       Media  Attack%    goodAttack
# ...

# %%
ultimos = poke.groupby('Generation')
# Aqui selecionamos os 10 ultimos pokemons da 1º geração
ultimos.get_group(1).tail(10)
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 159  147              Dratini    Dragon       NaN   41      64       45
# 160  148            Dragonair    Dragon       NaN   61      84       65
# 161  149            Dragonite    Dragon    Flying   91     134       95
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 164  150  MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
# 165  151                  Mew   Psychic       NaN  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary       Media  Attack%  \
# 156       95      125     85           1       True   91.666667      8.5
# ...

# %%
# Podemos agrupar duas colunas com o groupby
duas_categorias = poke.groupby(['Attack', 'Name'])
# Utilizando o first para encontrar os primeiros valores de attacks 
duas_categorias.first().tail(10)
# Out:
#                                   #   Type 1    Type 2   HP  Defense  Sp. Atk  \
# Attack Name
# 165    BanetteMega Banette      354    Ghost      None   64       75       93
#        GalladeMega Gallade      475  Psychic  Fighting   68       95       65
#        Rampardos                409     Rock      None   97       60       65
# 170    GarchompMega Garchomp    445   Dragon    Ground  108      115      120
#        KyuremBlack Kyurem       646   Dragon       Ice  125      100      120
# 180    DeoxysAttack Forme       386  Psychic      None   50       20      180
#        GroudonPrimal Groudon    383   Ground      Fire  100      160      150
#        RayquazaMega Rayquaza    384   Dragon    Flying  105      100      180
# 185    HeracrossMega Heracross  214      Bug  Fighting   80      115       40
# 190    MewtwoMega Mewtwo X      150  Psychic  Fighting  106      100      154
#
#                                 Sp. Def  Speed  Generation  Legendary  \
# Attack Name
# ...

# %% [markdown]
# **Objetivo: Encontrar os 10 mais fortes pokemons da geração 3**
#
# **Passos:**
#
# 1º Filtrar o dataframe com os nomes, ataques e geração que eu quero
# Podemos utilizar tanto uma expressão condicional, quanto o loc para realizar o filtragem
#
# 2º Escolher as colunas de nome e ataque do novo dataframe após as filtragens
#
# 3º Utilizar as funções para contar os valores dos dados

# %%
poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary       Media  Attack%  \
# ...

# %%
# Podemos fazer assim
poke[(poke['Generation'] == 1)]
# Filtrando apenas os pokemon que fazem parte da geração 3
Geração_1 = poke.loc[poke['Generation']== 1] # Ou assim, mesma coisa

# %% [markdown]
# **Agora temos todos os pokemons de Houen com seus valores de ataque**

# %%
Pokes = Geração_1[["Name","Attack"]]
Pokes
# Out:
#                       Name  Attack
# 0                Bulbasaur      49
# 1                  Ivysaur      62
# 2                 Venusaur      82
# 3    VenusaurMega Venusaur     100
# 4               Charmander      52
# ..                     ...     ...
# 161              Dragonite     134
# 162                 Mewtwo     110
# 163    MewtwoMega Mewtwo X     190
# 164    MewtwoMega Mewtwo Y     150
# 165                    Mew     100
#
# [166 rows x 2 columns]

# %% [markdown]
# **Agora tenho aplicar os metodos para selecionar os 10 primeiros em força de ataque**

# %%
mais_fortes = Pokes.sort_values(by="Attack", ascending = False).head(10).reset_index()
mais_fortes
# Out:
#    index                       Name  Attack
# 0    163        MewtwoMega Mewtwo X     190
# 1    141      GyaradosMega Gyarados     155
# 2    137          PinsirMega Pinsir     155
# 3     19      BeedrillMega Beedrill     150
# 4    164        MewtwoMega Mewtwo Y     150
# 5    154  AerodactylMega Aerodactyl     135
# 6    161                  Dragonite     134
# 7     74                    Machamp     130
# 8    120                     Rhydon     130
# 9    147                    Flareon     130

# %%
mais_fortes.plot(kind="bar", x="Name", y="Attack")
# Out:
# <AxesSubplot: xlabel='Name'>

# %%
mais_fortes2 = Pokes.groupby(["Attack","Name"]).count().tail(11)
mais_fortes2
# Out:
# Empty DataFrame
# Columns: []
# Index: [(130, Flareon), (130, Kingler), (130, Machamp), (130, Rhydon), (134, Dragonite), (135, AerodactylMega Aerodactyl), (150, BeedrillMega Beedrill), (150, MewtwoMega Mewtwo Y), (155, GyaradosMega Gyarados), (155, PinsirMega Pinsir), (190, MewtwoMega Mewtwo X)]

# %% [markdown]
# **Criando gráficos para visualizar melhor os dados**
#
# 1º Sites que me ajudaram: https://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot#bar-plot-of-column-values

# %%
mais_fortes.plot(kind="bar", x="Name", y="Attack")
# Out:
# <AxesSubplot: xlabel='Name'>

# %%
# Pokes.groupby(["Attack", "Name"]).count().head(10)

# %%
# Pokes.count()
# Pokes.groupby(["Attack"]).max().tail()

# %%
poke.groupby((poke["Generation"] == 1) & (poke["Name"] == "Mewt")).mean()
# poke.get_group('Name')
# poke.groupby('Name')[['Attack', "Defense"]].value_counts()
# Out:
#                #        HP    Attack  Defense  Sp. Atk  Sp. Def    Speed  \
# False  362.81375  69.25875  79.00125  73.8425    72.82  71.9025  68.2775
#
#        Generation  Legendary      Media   Attack%
# False     3.32375    0.08125  74.034167  7.900125
