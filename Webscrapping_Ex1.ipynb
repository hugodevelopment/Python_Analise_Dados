# %% [markdown]
# **Testando webscapping com dados de investimentos**
#
# A ideia é pegar os dados da seguinte tabela dos sites meus dividendos, pegando as empresas e seu valor de mercado

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# URL da página web que você deseja fazer o scraping
url = "https://www.meusdividendos.com/empresas/ranking?q=valorMercado"

# Fazendo a requisição para a URL
response = requests.get(url)

# Criando o objeto BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Encontrando a tabela no HTML
table = soup.find('table')


# Lendo a tabela com o pandas
df = pd.read_html(str(table))[0]
print(df)

# Selecionando apenas as colunas desejadas
df = df[['Empresa', 'Sigla', 'Valor de Mercado']]

# Salvando o DataFrame em um arquivo Excel
df.to_excel("ranking_empresas_bovespa.xlsx", index=False)
# Out:
#        #           Empresa Sigla  Valor de Mercado  Cotação  Lucro  Yield  \
# 0      1     PETROBRASPETR  PETR      5.421293e+11    41.60    NaN    NaN
# 1      2          VALEVALE  VALE      3.467142e+11    65.40    NaN    NaN
# 2      3     AMBEV S/AABEV  ABEV      1.969417e+11    12.50    NaN    NaN
# 3      4  ITAUUNIBANCOITUB  ITUB      1.513273e+11    23.00    NaN    NaN
# 4      5        BRASILBBAS  BBAS      1.407493e+11    49.10    NaN    NaN
# ..   ...               ...   ...               ...      ...    ...    ...
# 347  348     VIAVAREJOVIIA  VIIA      0.000000e+00      NaN    NaN    NaN
# 348  349    BIOTOSCANAGBIO  GBIO      0.000000e+00     7.03    NaN    NaN
# 349  350     COSAN LTDCZLT  CZLT      0.000000e+00    29.20    NaN    NaN
# 350  351          PPLAPPLA  PPLA      0.000000e+00     3.85    NaN    NaN
# 351  352   WILSON SONSWSON  WSON      0.000000e+00    67.00    NaN    NaN
#
#      Dívida  Patrimônio
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
# ..      ...         ...
# 347     NaN         NaN
# 348     NaN         NaN
# 349     NaN         NaN
# 350     NaN         NaN
# 351     NaN         NaN
#
# [352 rows x 9 columns]
